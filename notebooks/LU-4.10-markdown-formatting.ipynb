# %% [markdown]
# # LU 4.10 - Markdown Formatting in Notebooks

# %% [markdown]
# ## Why this format matters
# - Makes fraud analysis easier to review
# - Highlights assumptions clearly
# - Improves handover quality

# %% [markdown]
# ## Example code block
# ```python
# suspicious = df[df['txn_amount'] > 5000]
# suspicious.head()
# ```

# %%
from src.fraudscope.notebook_markdown_template import print_markdown_template

print_markdown_template()
