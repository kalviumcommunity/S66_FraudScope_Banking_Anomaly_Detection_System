# %% [markdown]
# # LU 4.15 - Lists, Tuples, and Dictionaries
#
# This notebook demonstrates core Python data structures for transaction context building.

# %%
from src.fraudscope.data_structures import build_transaction_batch, build_record_keys, account_totals

records = build_transaction_batch()
keys = build_record_keys(records)
totals = account_totals(records)

print(records)
print(keys)
print(totals)
