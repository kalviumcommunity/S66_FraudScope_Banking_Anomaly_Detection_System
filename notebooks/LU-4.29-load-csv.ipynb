# %% [markdown]
# # LU 4.29 - Loading CSV Data into Pandas
#
# This notebook demonstrates loading CSV transaction files into Pandas DataFrames.

# %%
from src.fraudscope.pandas_csv_loader import load_transaction_csv

df = load_transaction_csv()
print(df.head())
