# %% [markdown]
# # LU 4.12 - Data Stage Organization
#
# This notebook defines where raw files, processed tables, and output artifacts should be stored.

# %%
from src.fraudscope.data_stage_policy import classify_artifact, print_stage_policy

print_stage_policy()

examples = [
    'data/raw/transactions_april.csv',
    'data/processed/transactions_clean.csv',
    'outputs/reports/anomalies_2026_04_15.csv',
]

for item in examples:
    print(item, '->', classify_artifact(item))

# %% [markdown]
# ## Stage Rules
# - Keep `data/raw` immutable
# - Save transformed outputs in `data/processed`
# - Store charts and reports in `outputs/`
