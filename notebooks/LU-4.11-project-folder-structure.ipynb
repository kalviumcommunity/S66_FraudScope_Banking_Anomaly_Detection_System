# %% [markdown]
# # LU 4.11 - Project Folder Structure
#
# This notebook explains the standard FraudScope directory layout for data science work.

# %% [markdown]
# ## Expected Structure
# - `data/raw` for original transaction logs
# - `data/processed` for cleaned datasets
# - `notebooks` for analysis notebooks
# - `outputs` for figures and reports

# %%
from src.fraudscope.folder_structure import print_structure_report

print_structure_report()
