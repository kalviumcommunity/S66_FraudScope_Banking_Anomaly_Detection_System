# %% [markdown]
# # LU 4.24 - Basic Math Operations on NumPy Arrays
#
# This notebook applies element-wise arithmetic operations to transaction amount arrays.

# %%
from src.fraudscope.numpy_math_ops import run_basic_math

results = run_basic_math([1200, 7800, 450, 15200])
for key, value in results.items():
    print(f'{key}: {value}')
