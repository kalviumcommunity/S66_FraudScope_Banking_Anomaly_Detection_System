# %% [markdown]
# # LU 4.8 - Code Cells vs Markdown Cells
#
# This notebook demonstrates when to use code cells and markdown cells in FraudScope analysis notebooks.

# %% [markdown]
# ## Markdown Cell Example
#
# We are checking whether transaction amounts show high-value suspicious behavior over a threshold.

# %%
transaction_amounts = [250, 800, 12000, 430, 9800]
threshold = 5000
flagged = [amount for amount in transaction_amounts if amount > threshold]
flagged

# %% [markdown]
# ## Code/Markdown Guide

# %%
from src.fraudscope.notebook_cell_guide import print_cell_guide

print_cell_guide()
