# %% [markdown]
# # LU 4.13 - First Python Analysis Script
#
# This notebook validates the first script-based analysis run for sample banking transactions.

# %%
from pathlib import Path

summary_path = Path('outputs/reports/lu_4_13_summary.txt')
print(summary_path.read_text(encoding='utf-8'))
