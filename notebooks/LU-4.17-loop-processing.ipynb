# %% [markdown]
# # LU 4.17 - Loop-Based Iterative Processing
#
# This notebook demonstrates `for` and `while` loops for repeated transaction checks.

# %%
from src.fraudscope.loop_processing import count_high_value_for_loop, count_until_limit_while_loop

amounts = [1200, 7800, 450, 15200, 2300]
print(count_high_value_for_loop([float(value) for value in amounts]))
print(count_until_limit_while_loop([float(value) for value in amounts], limit=2))
