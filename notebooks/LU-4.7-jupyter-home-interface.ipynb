# %% [markdown]
# # LU 4.7 - Launching Jupyter and Understanding Home Interface
#
# This notebook explains how to launch Jupyter Notebook and use the home interface effectively in FraudScope.

# %% [markdown]
# ## Launch Commands
#
# 1. Open terminal in project root
# 2. Activate environment
# 3. Run `jupyter notebook`

# %%
from src.fraudscope.jupyter_startup_guide import print_jupyter_guide

print_jupyter_guide()

# %% [markdown]
# ## Home Interface Mapping
#
# - Use **Files** to browse `data/`, `notebooks/`, and `outputs/`
# - Use **Running** to stop unused sessions and save memory
# - Use **Upload** to add new transaction CSVs for analysis
# - Use **New** to create exploratory notebooks
