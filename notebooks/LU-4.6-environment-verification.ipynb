# %% [markdown]
# # LU 4.6 - Environment Verification and Python Syntax Basics
#
# This notebook verifies Python tooling and demonstrates beginner syntax used in FraudScope data workflows.

# %%
from src.fraudscope.environment_verify import verify_environment

for tool in verify_environment():
    print(f"{tool.name}: {'OK' if tool.available else 'MISSING'} -> {tool.details}")

# %% [markdown]
# ## Core Python Syntax Warm-up

# %%
transactions = [1200, 3400, 280, 9100]
mean_amount = sum(transactions) / len(transactions)
high_value = [amount for amount in transactions if amount > 3000]

print('Average amount:', mean_amount)
print('High value transactions:', high_value)
