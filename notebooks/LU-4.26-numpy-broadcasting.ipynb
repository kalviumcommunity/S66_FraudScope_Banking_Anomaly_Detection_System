# %% [markdown]
# # LU 4.26 - NumPy Broadcasting Basics
#
# This notebook demonstrates NumPy broadcasting for efficient array operations.

# %%
from src.fraudscope.numpy_broadcasting import run_broadcasting_demo

results = run_broadcasting_demo()
for key, value in results.items():
    print(f'{key}: {value}')
