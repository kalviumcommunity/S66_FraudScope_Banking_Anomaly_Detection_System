# %% [markdown]
# # LU 4.21 - Structured Python Code
#
# This notebook demonstrates a reusable pipeline structure with separate load, score, and summarize steps.

# %%
from src.fraudscope.structured_pipeline import run_pipeline

summary = run_pipeline()
print(summary)
