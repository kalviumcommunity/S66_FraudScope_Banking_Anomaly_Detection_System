# %% [markdown]
# # LU 4.20 - PEP8 Naming and Comments
#
# This notebook demonstrates readable variable naming and selective comments for fraud logic clarity.

# %%
from src.fraudscope.pep8_basics import evaluate_transaction_risk

result = evaluate_transaction_risk(transaction_amount=6400, hourly_transaction_count=5)
print(result)
