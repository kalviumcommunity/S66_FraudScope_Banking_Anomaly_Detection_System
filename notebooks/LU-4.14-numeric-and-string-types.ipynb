# %% [markdown]
# # LU 4.14 - Numeric and String Types
#
# This notebook demonstrates numeric and string type handling for transaction fields.

# %%
from src.fraudscope.type_basics import parse_transaction

sample = parse_transaction('15200', 'ATM')
sample

# %%
print(type(sample['amount']).__name__)
print(type(sample['channel']).__name__)
print(type(sample['is_high_value']).__name__)

# %% [markdown]
# ## Why this helps
# - Numeric types support threshold and statistical logic
# - String types support categorical grouping and cleaning
