# %% [markdown]
# # LU 4.28 - Creating Pandas DataFrames
#
# This notebook demonstrates creating Pandas DataFrames from transaction dictionaries.

# %%
from src.fraudscope.pandas_dataframe import create_transaction_dataframe, get_column_info

df = create_transaction_dataframe()
print(df)
print(get_column_info(df))
