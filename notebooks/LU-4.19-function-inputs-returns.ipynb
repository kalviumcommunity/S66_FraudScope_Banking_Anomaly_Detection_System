# %% [markdown]
# # LU 4.19 - Function Inputs and Returns
#
# This notebook demonstrates passing payload data into functions and using returned scoring results.

# %%
from src.fraudscope.function_io import score_from_payload

payload = {'account_id': 'A11', 'amount': 8400, 'transaction_count_last_hour': 6}
result = score_from_payload(payload)
print(result)
