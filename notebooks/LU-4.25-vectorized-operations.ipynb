# %% [markdown]
# # LU 4.25 - Vectorized Operations Instead of Python Loops
#
# This notebook demonstrates replacing Python loops with vectorized NumPy operations for efficient anomaly detection.

# %%
from src.fraudscope.numpy_vectorized import run_vectorized_threshold

results = run_vectorized_threshold([1200, 7800, 450, 15200, 2300], threshold=5000)
for key, value in results.items():
    print(f'{key}: {value}')
