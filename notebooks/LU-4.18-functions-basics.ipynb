# %% [markdown]
# # LU 4.18 - Defining and Calling Functions
#
# This notebook demonstrates reusable function patterns for transaction risk scoring.

# %%
from src.fraudscope.function_basics import compute_risk_score, label_reason, score_transaction

score = compute_risk_score(8200, 6)
reason = label_reason(score)
record = score_transaction(8200, 6)

print(score)
print(reason)
print(record)
