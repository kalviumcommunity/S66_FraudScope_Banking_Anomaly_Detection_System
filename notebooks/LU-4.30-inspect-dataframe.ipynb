# %% [markdown]
# # LU 4.30 - Inspecting DataFrames
#
# This notebook demonstrates DataFrame inspection using head(), info(), and describe().

# %%
from src.fraudscope.pandas_csv_loader import load_transaction_csv
from src.fraudscope.pandas_inspector import inspect_dataframe

df = load_transaction_csv()
info = inspect_dataframe(df)
print('Shape:', info['shape'])
print('Columns:', info['columns'])
