# %% [markdown]
# # LU 4.23 - Array Shape, Dimensions, and Indexing
#
# This notebook inspects NumPy array structure for shape, dimensions, and index-based access.

# %%
from src.fraudscope.numpy_shape_indexing import inspect_arrays

details = inspect_arrays()
for key, value in details.items():
    print(f'{key}: {value}')
