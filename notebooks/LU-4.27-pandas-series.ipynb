# %% [markdown]
# # LU 4.27 - Creating Pandas Series from Lists and Arrays
#
# This notebook demonstrates creating Pandas Series from transaction amount lists.

# %%
from src.fraudscope.pandas_series import create_amount_series, describe_series

amounts = create_amount_series([1200, 7800, 450, 15200])
print(amounts)
print(describe_series(amounts))
