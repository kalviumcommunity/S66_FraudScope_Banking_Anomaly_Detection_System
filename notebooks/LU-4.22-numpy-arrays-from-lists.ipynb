# %% [markdown]
# # LU 4.22 - NumPy Arrays from Lists
#
# This notebook converts Python lists to NumPy arrays for faster numeric workflows.

# %% [markdown]
# Install dependency if needed:
# ```bash
# pip install -r requirements.txt
# ```

# %%
from src.fraudscope.numpy_basics import create_amount_array

values = [1200, 7800, 450, 15200]
amount_array = create_amount_array([float(value) for value in values])
print(amount_array)
print(amount_array.shape)
print(amount_array.dtype)
