# %% [markdown]
# # LU 4.9 - Kernel Lifecycle Controls
#
# This notebook demonstrates how to run, interrupt, and restart kernels while analyzing data.

# %%
from src.fraudscope.kernel_lifecycle_guide import print_kernel_guide

print_kernel_guide()

# %% [markdown]
# ## Simulated Long Task
#
# Run this cell and use interrupt if needed to practice kernel control.

# %%
import time

for step in range(5):
    print(f'Processing batch {step + 1}/5')
    time.sleep(1)

print('Done')

# %% [markdown]
# After interrupting or restarting, run all cells from top to rebuild clean execution state.
